# %%
import pandas as pd
import numpy as np

# %%
#import file
raw_pd_rbd = "../data/raw/pd_rbd.xls"

pd_rbd = pd.read_excel(raw_pd_rbd, header=1)

# %%
pd_rbd.head(10)
# Out:
#   Unnamed: 0  Age (years) Gender  \
# 0       PD01         58.0      F
# 1       PD02         68.0      F
# 2       PD03         68.0      M
# 3       PD04         75.0      M
# 4       PD05         61.0      M
# 5       PD06         58.0      M
# 6       PD07         79.0      M
# 7       PD08         59.0      F
# 8       PD09         73.0      M
# 9       PD10         66.0      M
#
#   Positive history of Parkinson disease in family  \
# 0                                              No
# 1                                              No
# 2                                              No
# 3                                              No
# 4                                             Yes
# 5                                              No
# 6                                              No
# 7                                              No
# 8                                              No
# 9                                              No
#
#   Age of disease onset (years)  \
# 0                           56
# 1                           67
# 2                           67
# 3                      73.1616
# 4                         60.3
# 5                         57.5
# 6                           78
# 7                           57
# 8                           72
# 9                           65
#
#   Duration of disease from first symptoms (years) Antidepressant therapy  \
# 0                                               2                     No
# 1                                               1                     No
# 2                                               1                     No
# 3                                         1.83836                     No
# 4                                             0.7                     No
# 5                                             0.5                     No
# 6                                               1                     No
# 7                                               2          Yes (Aurorix)
# 8                                               1                     No
# 9                                               1         Yes (Trittico)
#
#   Antiparkinsonian medication Antipsychotic medication  \
# 0                          No                       No
# 1                          No                       No
# 2                          No                       No
# 3                          No                       No
# 4                          No                       No
# 5                          No                       No
# 6                          No                       No
# 7                          No                       No
# 8                          No                       No
# 9                          No                       No
#
#   Benzodiazepine medication  ...  Acceleration of speech timing (-/min2)  \
# 0                        No  ...                               -2.821769
# 1                        No  ...                                8.196296
# 2                        No  ...                                4.710260
# 3                        No  ...                               -9.094008
# 4                        No  ...                               11.766684
# 5                        No  ...                               13.378054
# 6                        No  ...                               -1.528592
# 7                        No  ...                               -4.117659
# 8                        No  ...                                5.250549
# 9                        No  ...                                4.990216
#
#    Duration of pause intervals (ms).1 Duration of voiced intervals (ms).1  \
# 0                          158.005040                          317.678279
# 1                          295.429641                          264.363532
# 2                          280.065517                          316.584135
# 3                          397.076923                          799.548684
# 4                          205.690524                          480.336538
# 5                          610.987903                          398.035000
# 6                          250.860262                          278.232143
# 7                          117.757775                          269.103867
# 8                          194.348657                          317.217271
# 9                          246.259036                          355.800197
#
#   Gaping                         in-between voiced\nintervals                   (-/min)  \
# 0                                          49.006920
# 1                                          40.564306
# 2                                          48.973638
# 3                                          18.685239
# 4                                          33.542347
# 5                                          18.181818
# 6                                          58.903965
# 7                                          68.645243
# 8                                          53.718626
# 9                                          38.193570
#
#   Duration of unvoiced stops (ms).1  \
# 0                            22.375
# 1                            26.875
# 2                            22.375
# 3                            49.375
# 4                            26.875
# 5                            49.375
# 6                            22.375
# 7                            17.875
# 8                            31.375
# 9                            40.375
#
#   Decay of unvoiced fricatives              (‰/min).1  \
# 0                                           0.588029
# 1                                          -0.824901
# 2                                          -0.954867
# 3                                           0.790737
# 4                                           0.074792
# 5                                           1.487822
# 6                                           0.173876
# 7                                           0.553993
# 8                                          -0.614473
# 9                                           0.500376
#
#   Relative loudness of respiration (dB).1  \
# 0                              -19.771488
# 1                              -23.256315
# 2                              -13.292394
# 3                              -25.076240
# 4                              -22.318787
# 5                              -25.077406
# 6                              -23.380437
# 7                              -17.444536
# 8                              -17.036517
# 9                              -20.196065
#
#   Pause intervals per respiration (-).1  \
# 0                                   6.0
# 1                                   4.0
# 2                                   4.0
# 3                                   2.0
# 4                                   5.0
# 5                                   2.0
# 6                                   5.0
# 7                                  13.5
# 8                                   4.0
# 9                                   3.5
#
#   Rate of speech respiration           (- /min)  \
# 0                                     13.809770
# 1                                     21.768707
# 2                                     22.522523
# 3                                     14.367816
# 4                                     14.611872
# 5                                     18.208717
# 6                                     17.849174
# 7                                      8.205128
# 8                                     21.248340
# 9                                     15.499370
#
#   Latency of\nrespiratory exchange (ms).1
# 0                              127.250000
# 1                              312.605000
# 2                              200.975000
# 3                              151.100000
# 4                              151.156250
# 5                              593.482143
# 6                              202.737500
# 7                              115.517857
# 8                               81.029255
# 9                               69.039286
#
# [10 rows x 65 columns]

# %%
pd_rbd.tail()
# Out:
#     Unnamed: 0  Age (years) Gender  \
# 133        NaN          NaN    NaN
# 134        NaN          NaN    NaN
# 135        NaN          NaN    NaN
# 136        NaN          NaN    NaN
# 137        NaN          NaN    NaN
#
#     Positive history of Parkinson disease in family  \
# 133                                             NaN
# 134                                             NaN
# 135                                             NaN
# 136                                             NaN
# 137                                             NaN
#
#     Age of disease onset (years)  \
# 133                          NaN
# 134                          NaN
# 135                          NaN
# 136                          NaN
# 137                          NaN
#
#     Duration of disease from first symptoms (years) Antidepressant therapy  \
# 133                                             NaN                    NaN
# 134                                             NaN                    NaN
# 135                                             NaN                    NaN
# 136                                             NaN                    NaN
# 137                                             NaN                    NaN
#
#     Antiparkinsonian medication Antipsychotic medication  \
# 133                         NaN                      NaN
# 134                         NaN                      NaN
# 135                         NaN                      NaN
# 136                         NaN                      NaN
# 137                         NaN                      NaN
#
#     Benzodiazepine medication  ...  Acceleration of speech timing (-/min2)  \
# 133                       NaN  ...                                     NaN
# 134                       NaN  ...                                     NaN
# 135                       NaN  ...                                     NaN
# 136                       NaN  ...                                     NaN
# 137                       NaN  ...                                     NaN
#
#      Duration of pause intervals (ms).1 Duration of voiced intervals (ms).1  \
# 133                                 NaN                                 NaN
# 134                                 NaN                                 NaN
# 135                                 NaN                                 NaN
# 136                                 NaN                                 NaN
# 137                                 NaN                                 NaN
#
#     Gaping                         in-between voiced\nintervals                   (-/min)  \
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#     Duration of unvoiced stops (ms).1  \
# 133                               NaN
# 134                               NaN
# 135                               NaN
# 136                               NaN
# 137                               NaN
#
#     Decay of unvoiced fricatives              (‰/min).1  \
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#     Relative loudness of respiration (dB).1  \
# 133                                     NaN
# 134                                     NaN
# 135                                     NaN
# 136                                     NaN
# 137                                     NaN
#
#     Pause intervals per respiration (-).1  \
# 133                                   NaN
# 134                                   NaN
# 135                                   NaN
# 136                                   NaN
# 137                                   NaN
#
#     Rate of speech respiration           (- /min)  \
# 133                                           NaN
# 134                                           NaN
# 135                                           NaN
# 136                                           NaN
# 137                                           NaN
#
#     Latency of\nrespiratory exchange (ms).1
# 133                                     NaN
# 134                                     NaN
# 135                                     NaN
# 136                                     NaN
# 137                                     NaN
#
# [5 rows x 65 columns]

# %%
pd_rbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 65 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Unnamed: 0                                                                            130 non-null    object
#  1   Age (years)                                                                           130 non-null    float64
#  2   Gender                                                                                130 non-null    object
#  3   Positive history of Parkinson disease in family                                       130 non-null    object
#  4   Age of disease onset (years)                                                          130 non-null    object
#  5   Duration of disease from first symptoms (years)                                       130 non-null    object
#  6   Antidepressant therapy                                                                130 non-null    object
#  7   Antiparkinsonian medication                                                           130 non-null    object
#  8   Antipsychotic medication                                                              130 non-null    object
#  9   Benzodiazepine medication                                                             130 non-null    object
#  10  Levodopa equivalent (mg/day)                                                          131 non-null    float64
#  11  Clonazepam (mg/day)                                                                   130 non-null    float64
#  12  Hoehn & Yahr scale (-)                                                                130 non-null    object
#  13  UPDRS III total (-)                                                                   130 non-null    object
#  14  18. Speech                                                                            131 non-null    object
#  15  19. Facial Expression                                                                 130 non-null    object
#  16  20. Tremor at Rest - head                                                             130 non-null    object
#  17  20. Tremor at Rest - RUE                                                              130 non-null    object
#  18  20. Tremor at Rest - LUE                                                              130 non-null    object
#  19  20. Tremor at Rest - RLE                                                              130 non-null    object
#  20  20. Tremor at Rest - LLE                                                              130 non-null    object
#  21  21. Action or Postural Tremor - RUE                                                   130 non-null    object
#  22  21. Action or Postural Tremor - LUE                                                   130 non-null    object
#  23  22. Rigidity - neck                                                                   130 non-null    object
#  24  22. Rigidity - RUE                                                                    130 non-null    object
#  25  22. Rigidity - LUE                                                                    130 non-null    object
#  26  22. Rigidity - RLE                                                                    130 non-null    object
#  27  22. Rigidity - LLE                                                                    130 non-null    object
#  28  23.Finger Taps - RUE                                                                  130 non-null    object
#  29  23.Finger Taps - LUE                                                                  130 non-null    object
#  30  24. Hand Movements  - RUE                                                             130 non-null    object
#  31  24. Hand Movements  - LUE                                                             130 non-null    object
#  32  25. Rapid Alternating Movements - RUE                                                 130 non-null    object
#  33  25. Rapid Alternating Movements -  LUE                                                130 non-null    object
#  34  26. Leg Agility - RLE                                                                 130 non-null    object
#  35  26. Leg Agility - LLE                                                                 130 non-null    object
#  36  27.  Arising from Chair                                                               130 non-null    object
#  37  28. Posture                                                                           130 non-null    object
#  38  29. Gait                                                                              130 non-null    object
#  39  30. Postural Stability                                                                130 non-null    object
#  40  31. Body Bradykinesia and Hypokinesia                                                 130 non-null    object
#  41  Entropy of speech timing (-)                                                          130 non-null    float64
#  42  Rate of speech timing (-/min)                                                         130 non-null    float64
#  43  Acceleration of speech timing                                (-/min2)                 130 non-null    float64
#  44  Duration of pause intervals (ms)                                                      130 non-null    float64
#  45  Duration of voiced intervals (ms)                                                     130 non-null    float64
#  46  Gaping                          in-between voiced
# intervals  (-/min)                  130 non-null    float64
#  47  Duration of unvoiced stops (ms)                                                       130 non-null    float64
#  48  Decay of unvoiced fricatives              (‰/min)                                     130 non-null    float64
#  49  Relative loudness of respiration (dB)                                                 130 non-null    float64
#  50  Pause intervals per respiration (-)                                                   130 non-null    float64
#  51  Rate of speech respiration                (-/min)                                     130 non-null    float64
#  52  Latency of
# respiratory exchange (ms)                                                  130 non-null    float64
#  53  Entropy of speech timing (-).1                                                        130 non-null    float64
#  54  Rate of speech timing (-/min).1                                                       130 non-null    float64
#  55  Acceleration of speech timing (-/min2)                                                130 non-null    float64
#  56  Duration of pause intervals (ms).1                                                    130 non-null    float64
#  57  Duration of voiced intervals (ms).1                                                   130 non-null    float64
#  58  Gaping                         in-between voiced
# intervals                   (-/min)  130 non-null    float64
#  59  Duration of unvoiced stops (ms).1                                                     130 non-null    float64
#  60  Decay of unvoiced fricatives              (‰/min).1                                   130 non-null    float64
#  61  Relative loudness of respiration (dB).1                                               130 non-null    float64
#  62  Pause intervals per respiration (-).1                                                 130 non-null    float64
#  63  Rate of speech respiration           (- /min)                                         130 non-null    float64
#  64  Latency of
# respiratory exchange (ms).1                                                130 non-null    float64
# dtypes: float64(27), object(38)
# memory usage: 70.2+ KB

# %%
#remove empty rows
pd_rbd = pd_rbd.dropna()

# %%
columns = {'Unnamed: 0':'id', 'Age (years)':'age', 'Gender':'gender',
       'Positive history of Parkinson disease in family':'fam_hist',
       'Age of disease onset (years)':'onset_age',
       'Duration of disease from first symptoms (years)': 'duration',
       'Antidepressant therapy':'depress_med', 'Antiparkinsonian medication':'pd_med',
       'Antipsychotic medication':'psych_med', 'Benzodiazepine medication':'benz_med',
       'Levodopa equivalent (mg/day)':'levodopa', 'Clonazepam (mg/day)':'clonazepam',
       'Hoehn & Yahr scale (-)':'hy_scale', 'UPDRS III total (-)':'updrs_total', '18. Speech':'updrs_speech',
       '19. Facial Expression':'updrs_face_exp', '20. Tremor at Rest - head':'updrs_tremor_rest_head',
       '20. Tremor at Rest - RUE':'updrs_trem_rest_RUE', '20. Tremor at Rest - LUE':'updrs_trem_rest_LUE',
       '20. Tremor at Rest - RLE':'updrs_trem_rest_RLE', '20. Tremor at Rest - LLE':'updrs_trem_rest_LLE',
       '21. Action or Postural Tremor - RUE':'updrs_trem_act_RUE',
       '21. Action or Postural Tremor - LUE':'updrs_trem_act_LUE', '22. Rigidity - neck':'updrs_rig_neck',
       '22. Rigidity - RUE':'updrs_rig_RUE', '22. Rigidity - LUE':'updrs_rig_LUE', 
       '22. Rigidity - RLE':'updrs_rig_RLE','22. Rigidity - LLE':'updrs_rig_LLE', 
       '23.Finger Taps - RUE':'updrs_taps_RUE', '23.Finger Taps - LUE':'updrs_taps_LUE',
       '24. Hand Movements  - RUE':'updrs_hand_RUE', '24. Hand Movements  - LUE':'updrs_hand_LUE',
       '25. Rapid Alternating Movements - RUE':'updrs_altmove_RUE',
       '25. Rapid Alternating Movements -  LUE':'updrs_altmove_LUE','26. Leg Agility - RLE':'updrs_leg_RLE',
       '26. Leg Agility - LLE':'updrs_leg_LLE', '27.  Arising from Chair ':'updrs_rise_chair', 
       '28. Posture':'updrs_posture','29. Gait':'updrs_gait', '30. Postural Stability':'updrs_post_stab',
       '31. Body Bradykinesia and Hypokinesia':'updrs_brady_hypo', 'Entropy of speech timing (-)':'pass_est',
       'Rate of speech timing (-/min)':'pass_rst',
       'Acceleration of speech timing                                (-/min2)':'pass_ast',
       'Duration of pause intervals (ms)':'pass_dpi', 'Duration of voiced intervals (ms)':'pass_dvi',
       'Gaping                          in-between voiced\nintervals  (-/min)':'pass_gvi',
       'Duration of unvoiced stops (ms)':'pass_dus',
       'Decay of unvoiced fricatives              (‰/min)':'pass_duf',
       'Relative loudness of respiration (dB)':'pass_rlr',
       'Pause intervals per respiration (-)':'pass_pir',
       'Rate of speech respiration                (-/min)':'pass_rsr',
       'Latency of\nrespiratory exchange (ms)':'pass_lre',
       'Entropy of speech timing (-).1':'mono_est', 'Rate of speech timing (-/min).1':'mono_rst',
       'Acceleration of speech timing (-/min2)':'mono_ast',
       'Duration of pause intervals (ms).1':'mono_dpi',
       'Duration of voiced intervals (ms).1':'mono_dvi',
       'Gaping                         in-between voiced\nintervals                   (-/min)':'mono_gvi',
       'Duration of unvoiced stops (ms).1':'mono_dus',
       'Decay of unvoiced fricatives              (‰/min).1':'mono_duf',
       'Relative loudness of respiration (dB).1':'mono_rlr',
       'Pause intervals per respiration (-).1':'mono_pir',
       'Rate of speech respiration           (- /min)':'mono_rsr',
       'Latency of\nrespiratory exchange (ms).1':'mono_lre'
        }

# %%
#rename columns
pd_rbd = pd_rbd.rename(columns=columns)

# %%
#remove columns with only 1 value
def remove_cols(df):
    remove = []
    for col in df:
        if len(df[col].unique()) == 1:
            remove.append(col)
    df = df.drop(columns=remove)
    return df

# %%
pd_rbd = remove_cols(pd_rbd)

# %%
#rename and encode id column
pd_rbd['id'] = pd_rbd['id'].str[:2]
pd_rbd = pd_rbd.rename(columns={'id':'status'})

# %%
#encode categorical data
encode = {'status':{'PD':1, 'RB':2, 'HC':0},
          'gender':{'F':0, 'M':1},
          'fam_hist': {'No':0, 'Yes':1, '-':-1},
          'depress_med':{'No':0, 'Yes (Aurorix)':1, 'Yes (Trittico)':2, 'Yes (Remood)':3,
                         'Yes (Zoloft)':4, 'Yes (Anafranil)':5, 'Yes (Citalec)':6,
                         'Yes (Velaxin)':7, 'Yes (Asentra)':8, 'Yes (Cipralex)':9 },
          'benz_med':{'No':0, 'Yes (Rivotril)':1, 'Yes (Xanax)':2, 'Yes (Neurol)':3}
          }
pd_rbd.replace(encode, inplace=True)

# %%
#fill in rows with now data with nan
pd_rbd = pd_rbd.replace('-', np.nan)

# %%
#convert data types
pd_rbd['hy_scale'] = pd_rbd['hy_scale'].astype(float)
pd_rbd['age'] = pd_rbd['age'].astype(int)

# %%
#create age range column
bins = [30, 40, 50, 60, 70, 80, 90]
labels = ['30-39', '40-49', '50-59', '60-69', '70-79','80+']
pd_rbd['age_range'] = pd.cut(pd_rbd.age, bins, labels = labels,include_lowest = True)

# %%
#rearrange columns
cols = pd_rbd.columns.tolist()
cols = cols[:2] + cols[-1:] + cols[2:62]
pd_rbd_final = pd_rbd[cols]

# %%
pd_rbd_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 0 to 129
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   status                  130 non-null    int64
#  1   age                     130 non-null    int64
#  2   age_range               130 non-null    category
#  3   gender                  130 non-null    int64
#  4   fam_hist                130 non-null    int64
#  5   onset_age               80 non-null     float64
#  6   duration                80 non-null     float64
#  7   depress_med             130 non-null    int64
#  8   benz_med                130 non-null    int64
#  9   clonazepam              130 non-null    float64
#  10  hy_scale                30 non-null     float64
#  11  updrs_total             80 non-null     float64
#  12  updrs_speech            80 non-null     float64
#  13  updrs_face_exp          80 non-null     float64
#  14  updrs_tremor_rest_head  80 non-null     float64
#  15  updrs_trem_rest_RUE     80 non-null     float64
#  16  updrs_trem_rest_LUE     80 non-null     float64
#  17  updrs_trem_rest_RLE     80 non-null     float64
#  18  updrs_trem_rest_LLE     80 non-null     float64
#  19  updrs_trem_act_RUE      80 non-null     float64
#  20  updrs_trem_act_LUE      80 non-null     float64
#  21  updrs_rig_neck          80 non-null     float64
#  22  updrs_rig_RUE           80 non-null     float64
#  23  updrs_rig_LUE           80 non-null     float64
#  24  updrs_rig_RLE           80 non-null     float64
#  25  updrs_rig_LLE           80 non-null     float64
#  26  updrs_taps_RUE          80 non-null     float64
#  27  updrs_taps_LUE          80 non-null     float64
#  28  updrs_hand_RUE          80 non-null     float64
#  29  updrs_hand_LUE          80 non-null     float64
#  30  updrs_altmove_RUE       80 non-null     float64
#  31  updrs_altmove_LUE       80 non-null     float64
#  32  updrs_leg_RLE           80 non-null     float64
#  33  updrs_leg_LLE           80 non-null     float64
#  34  updrs_rise_chair        80 non-null     float64
#  35  updrs_posture           80 non-null     float64
#  36  updrs_gait              80 non-null     float64
#  37  updrs_post_stab         80 non-null     float64
#  38  updrs_brady_hypo        80 non-null     float64
#  39  pass_est                130 non-null    float64
#  40  pass_rst                130 non-null    float64
#  41  pass_ast                130 non-null    float64
#  42  pass_dpi                130 non-null    float64
#  43  pass_dvi                130 non-null    float64
#  44  pass_gvi                130 non-null    float64
#  45  pass_dus                130 non-null    float64
#  46  pass_duf                130 non-null    float64
#  47  pass_rlr                130 non-null    float64
#  48  pass_pir                130 non-null    float64
#  49  pass_rsr                130 non-null    float64
#  50  pass_lre                130 non-null    float64
#  51  mono_est                130 non-null    float64
#  52  mono_rst                130 non-null    float64
#  53  mono_ast                130 non-null    float64
#  54  mono_dpi                130 non-null    float64
#  55  mono_dvi                130 non-null    float64
#  56  mono_gvi                130 non-null    float64
#  57  mono_dus                130 non-null    float64
#  58  mono_duf                130 non-null    float64
#  59  mono_rlr                130 non-null    float64
#  60  mono_pir                130 non-null    float64
#  61  mono_rsr                130 non-null    float64
#  62  mono_lre                130 non-null    float64
# dtypes: category(1), float64(56), int64(6)
# memory usage: 64.3 KB

# %%
pd_rbd_final.head()
# Out:
#    status  age age_range  gender  fam_hist  onset_age  duration  depress_med  \
# 0       1   58     50-59       0         0  56.000000  2.000000            0
# 1       1   68     60-69       0         0  67.000000  1.000000            0
# 2       1   68     60-69       1         0  67.000000  1.000000            0
# 3       1   75     70-79       1         0  73.161644  1.838356            0
# 4       1   61     60-69       1         1  60.300000  0.700000            0
#
#    benz_med  clonazepam  ...   mono_ast    mono_dpi    mono_dvi   mono_gvi  \
# 0         0         0.0  ...  -2.821769  158.005040  317.678279  49.006920
# 1         0         0.0  ...   8.196296  295.429641  264.363532  40.564306
# 2         0         0.0  ...   4.710260  280.065517  316.584135  48.973638
# 3         0         0.0  ...  -9.094008  397.076923  799.548684  18.685239
# 4         0         0.0  ...  11.766684  205.690524  480.336538  33.542347
#
#    mono_dus  mono_duf   mono_rlr  mono_pir   mono_rsr   mono_lre
# 0    22.375  0.588029 -19.771488       6.0  13.809770  127.25000
# 1    26.875 -0.824901 -23.256315       4.0  21.768707  312.60500
# 2    22.375 -0.954867 -13.292394       4.0  22.522523  200.97500
# 3    49.375  0.790737 -25.076240       2.0  14.367816  151.10000
# 4    26.875  0.074792 -22.318787       5.0  14.611872  151.15625
#
# [5 rows x 63 columns]

# %%
#Save to local drive
#pd_rbd_final.to_csv('../data/interim/analysis_set.csv', index=False)
